# %%
# Célula 1: Autenticação
from google.colab import auth

# Solicita autenticação do usuário
auth.authenticate_user()

print('Authenticated successfully!')
# Out:
# Authenticated successfully!

# %%
# Célula 2: Instalação das bibliotecas
# !pip install -q gcsfs pyarrow

print('Libraries installed!')
# Out:
# Libraries installed!

# %%
# Célula 3: Leitura e visualização dos dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. ESCOLHA QUAL ANÁLISE VOCÊ QUER VER
# Exemplos: 'veteran_hosts_analysis', 'price_seasonality_analysis', 'top_listings_by_reviews', etc.
analysis_name = 'most_reviewed_hosts'


# 3. CONSTRUA O CAMINHO COMPLETO PARA OS DADOS NO GCS
# O 'gs://' indica ao pandas para usar a biblioteca gcsfs que instalamos
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'

print(f"Reading data from: {gcs_path}")

# 4. LEIA OS ARQUIVOS PARQUET DIRETAMENTE PARA UM DATAFRAME PANDAS
try:
    df = pd.read_parquet(gcs_path)

    # 5. MOSTRE O DATAFRAME!
    print(f"\nDisplaying results for: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nAn error occurred: {e}")
    print("Please check if the bucket name and analysis name are correct and if the files exist at the specified location.")
# Out:
# Reading data from: gs://airbnb-data-pedro/results/most_reviewed_hosts
#
# Displaying results for: most_reviewed_hosts
#      host_id        host_name  total_reviews  total_listings
# 0    6000862      Omar Do Rio           5684             214
# 1  310319158          Suellen           4527             122
# 2   74463624           Mozart           4155              86
# 3   46664224           Rafael           4048              52
# 4    2513825           Newton           3576              65
# 5   36744189           Monica           3466              41
# 6   15533343             Yuri           3325              44
# 7    1982737          Estadia           2806             124
# 8  347487511          Rodrigo           2710              79
# 9   29475411  Bruno & Ricardo           2571              30

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'price_by_room_type_neighbourhood'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/price_by_room_type_neighbourhood
#
# Exibindo resultados para: price_by_room_type_neighbourhood
#           room_type    neighbourhood_cleansed  avg_price  total_listings
# 0       Shared room               São Conrado   25000.00               1
# 1   Entire home/apt                   Estácio   13113.97              39
# 2        Hotel room                Copacabana   12688.00               2
# 3   Entire home/apt                       Joá    7194.78             135
# 4   Entire home/apt               Coelho Neto    5680.00               2
# 5   Entire home/apt               São Conrado    4427.25             200
# 6   Entire home/apt                Portuguesa    2761.88               8
# 7      Private room                 Itanhangá    2696.15              66
# 8   Entire home/apt                 Itanhangá    2624.72             101
# 9   Entire home/apt         Alto da Boa Vista    2378.50              32
# ...

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'daily_availability'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/daily_availability
#
# Exibindo resultados para: daily_availability
#    calendar_date  total_listings  available_listings  pct_available
# 0     2025-03-19            2808                 485          17.27
# 1     2025-03-20           36748                9054          24.64
# 2     2025-03-21           42013               15861          37.75
# 3     2025-03-22           42013               18106          43.10
# 4     2025-03-23           42013               20855          49.64
# 5     2025-03-24           42013               22308          53.10
# 6     2025-03-25           42013               23068          54.91
# 7     2025-03-26           42013               23371          55.63
# 8     2025-03-27           42013               24095          57.35
# 9     2025-03-28           42013               23759          56.55
# 10    2025-03-29           42013               23485          55.90
# ...

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'top_listings_by_reviews'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/top_listings_by_reviews
#
# Exibindo resultados para: top_listings_by_reviews
#          id                                               name  \
# 0  10730455      COPACABANA,PRAIA/METRO,MELHOR CUSTO BENEFÍCIO
# 1    494903  Casablanca 1 Mediterranean Style Beachfront House
# 2    273463     Apto de 2 qtos com vista para Lagoa e  garagem
# 3     70080    Apart-hotel em Ipanema com garagem e  camareira
# 4  17865987     COPACABANA BEACH BOUTIQUE LUXURY SPACE 5 *****
# 5    996602     Apenas 3 min caminhando até a Praia Copacabana
# 6   2092178  Copacabana Beach - Av Atlântica (Sea View - 11th)
# 7  19181931          RIO DE JANEIRO,PRÓXIMO PRAIA/METRO,,WI-FI
# 8  47118316     Suíte de hotel até 2 pessoas com Café da Manha
# 9  14199323            PRIVATE ROOM in Copacabana with AC UNIT
#
#    number_of_reviews  price            city
# 0                726  115.0  rio-de-janeiro
# 1                712  276.0  rio-de-janeiro
# ...

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'superhost_impact'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/superhost_impact
#
# Exibindo resultados para: superhost_impact
#   host_is_superhost  total_listings  avg_rating  avg_price
# 0                 f           27945        4.75     786.17
# 1                 t           12848        4.88     597.75

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'occupancy_rate_estimation'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/occupancy_rate_estimation
#
# Exibindo resultados para: occupancy_rate_estimation
#              listing_id  booked_days  total_days  occupancy_rate
# 0              24515578          365         365           100.0
# 1    613014401412604408          365         365           100.0
# 2              52636787          365         365           100.0
# 3               2728880          365         365           100.0
# 4              41563890          365         365           100.0
# ..                  ...          ...         ...             ...
# 95   617761612281492865          365         365           100.0
# 96   946353553693899686          365         365           100.0
# 97  1035471371659233714          365         365           100.0
# 98  1290431971846573541          365         365           100.0
# 99  1297351335923922927          365         365           100.0
#
# [100 rows x 4 columns]

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'most_reviewed_hosts'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/most_reviewed_hosts
#
# Exibindo resultados para: most_reviewed_hosts
#      host_id        host_name  total_reviews  total_listings
# 0    6000862      Omar Do Rio           5684             214
# 1  310319158          Suellen           4527             122
# 2   74463624           Mozart           4155              86
# 3   46664224           Rafael           4048              52
# 4    2513825           Newton           3576              65
# 5   36744189           Monica           3466              41
# 6   15533343             Yuri           3325              44
# 7    1982737          Estadia           2806             124
# 8  347487511          Rodrigo           2710              79
# 9   29475411  Bruno & Ricardo           2571              30

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'price_distribution_by_property_type'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/price_distribution_by_property_type
#
# Exibindo resultados para: price_distribution_by_property_type
#                         property_type  listing_count  avg_price  median_price
# 0                  Entire rental unit          25129     717.85         377.0
# 1         Private room in rental unit           4493     392.29         220.0
# 2                         Entire home           1931    2005.62         630.0
# 3                        Entire condo           1665     696.18         405.0
# 4                Private room in home           1324     279.89         188.0
# 5                         Entire loft            772     407.42         262.0
# 6           Entire serviced apartment            714     562.83         380.0
# 7               Private room in condo            361     296.20         189.0
# 8   Private room in bed and breakfast            319     388.53         297.0
# ...

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'listings_without_recent_reviews'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/listings_without_recent_reviews
#
# Exibindo resultados para: listings_without_recent_reviews
#           id                                            name last_review_date  \
# 0     321637              NEW WORLD LODGINGS #Caledonia Room       2012-02-21
# 1     328626          OLYMPIC GAMES 2016 - in Rio de Janeiro       2012-02-21
# 2     786954               AAABSOLUTELY COOLEST 1BR - LEBLON       2013-01-03
# 3     496174               Room 4 World Cup close 2 Maracanã       2013-02-14
# 4     352718               Copacabana, Posto 06,   Um quarto       2013-02-14
# ..       ...                                             ...              ...
# 95  12007665  Quarto Confortável + Garagem - Casa de Família       2016-08-15
# 96  12844605    Frente para o mar, com piscina e pé na areia       2016-08-15
# 97   1885051               Room for Couple in Rio de Janeiro       2016-08-16
# ...

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'new_listings_trend'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/new_listings_trend
#
# Exibindo resultados para: new_listings_trend
#     first_review_month  count
# 0           2010-06-01      1
# 1           2010-07-01      1
# 2           2010-10-01      1
# 3           2011-03-01      4
# 4           2011-05-01      1
# ..                 ...    ...
# 166         2024-11-01    888
# 167         2024-12-01    744
# 168         2025-01-01   2335
# 169         2025-02-01    945
# 170         2025-03-01   2137
#
# [171 rows x 2 columns]

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'general_metrics'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/general_metrics
#
# Exibindo resultados para: general_metrics
#    total_listings  avg_price  min_price  max_price  unique_room_types  \
# 0           42013     720.28       30.0   500000.0                  4
#
#    unique_neighbourhoods  unique_hosts
# 0                    153         24791

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'top_neighborhoods_by_price'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/top_neighborhoods_by_price
#
# Exibindo resultados para: top_neighborhoods_by_price
#     neighbourhood_cleansed  total_listings  avg_price  min_price  max_price
# 0                  Estácio              78    6658.01       51.0   500000.0
# 1                      Joá             140    6653.39      124.0    24643.0
# 2              São Conrado             313    3001.75      110.0    45000.0
# 3                 Anchieta               2    2665.00      232.0     5098.0
# 4                Itanhangá             162    2657.59       72.0   144799.0
# 5              Coelho Neto               5    2635.60       62.0    11412.0
# 6               Santíssimo              10    1454.30      109.0    11412.0
# 7                 Curicica              72    1424.36       61.0    81239.0
# 8                   Galeão               2    1316.00      257.0     2375.0
# 9                    Lagoa             261    1278.32      107.0    39600.0
# ...

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'veteran_hosts_analysis'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/veteran_hosts_analysis
#
# Exibindo resultados para: veteran_hosts_analysis
#          host_id       host_name  total_listings first_listing_date
# 0           3607             Ana               2         2008-10-13
# 1          11739            Eric               9         2009-03-29
# 2          19065          Morena               5         2009-05-28
# 3          34105         Giselle               2         2009-08-26
# 4          38907    Chris & Gian               1         2009-09-16
# ...          ...             ...             ...                ...
# 24782  684484691  Rosemere Maria               2         2025-03-15
# 24783  684472712      Jacqueline               1         2025-03-15
# 24784  684637216         Elziane               1         2025-03-16
# 24785  684805701          Ariane               1         2025-03-17
# 24786  684789410        Cristian               1         2025-03-17
#
# [24787 rows x 4 columns]

# %%
# Célula para Leitura e Visualização dos Dados
import pandas as pd

# 1. ATUALIZE COM O NOME DO SEU BUCKET
BUCKET_NAME = 'airbnb-data-pedro'

# 2. NOME DA ANÁLISE PARA VISUALIZAR
analysis_name = 'price_seasonality_analysis'

# 3. Caminho completo para os dados no GCS
gcs_path = f'gs://{BUCKET_NAME}/results/{analysis_name}'
print(f"Lendo dados de: {gcs_path}")

try:
    # 4. Leia os arquivos Parquet diretamente para um DataFrame Pandas
    df = pd.read_parquet(gcs_path)

    # 5. Mostre o DataFrame!
    print(f"\nExibindo resultados para: {analysis_name}")
    display(df)

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("Verifique se o nome do bucket e da análise estão corretos.")
# Out:
# Lendo dados de: gs://airbnb-data-pedro/results/price_seasonality_analysis
#
# Exibindo resultados para: price_seasonality_analysis
#               city  month  average_price
# 0   rio-de-janeiro      1         854.40
# 1   rio-de-janeiro      2         848.61
# 2   rio-de-janeiro      3         826.81
# 3   rio-de-janeiro      4         788.38
# 4   rio-de-janeiro      5         765.39
# 5   rio-de-janeiro      6         757.84
# 6   rio-de-janeiro      7         783.19
# 7   rio-de-janeiro      8         786.10
# 8   rio-de-janeiro      9         812.20
# 9   rio-de-janeiro     10         846.20
# 10  rio-de-janeiro     11         843.69
# 11  rio-de-janeiro     12         850.48
